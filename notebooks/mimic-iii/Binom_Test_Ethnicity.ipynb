# %%
# Imports
from IPython.display import Image
import pandas as pd
import numpy as np
from scipy.stats import binom_test

# %%
PATH = '/content/drive/My Drive/Master/UFMG/Dissertation/Exploration/'

# %%
# READ CSV - Method 2 (Drive)
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Read tables

# %% [markdown]
# ### Patients table

# %%
mimic_patients_df = pd.read_csv(PATH + 'mimic-III/PATIENTS.csv')

# %% [markdown]
# ### Admission table

# %%
mimic_admission_df = pd.read_csv(PATH + 'mimic-III/ADMISSIONS.csv')

# %% [markdown]
# #### Merge both tables and calculate true age

# %%
# Merge patient and admission tables
mimic_patients_admission_df = pd.merge(mimic_admission_df, mimic_patients_df, on = 'SUBJECT_ID' , how = 'inner')

# %%
# ADMITTIME and DOB objects to datetime
mimic_patients_admission_df["ADMITTIME"] = pd.to_datetime(mimic_patients_admission_df["ADMITTIME"], format='%Y%m%d %H:%M:%S')
mimic_patients_admission_df["DOB"] = pd.to_datetime(mimic_patients_admission_df["DOB"], format='%Y%m%d %H:%M:%S')

# True age
mimic_patients_admission_df["AGES"] = mimic_patients_admission_df["ADMITTIME"].sub(mimic_patients_admission_df["DOB"]).dt.days/365.242

# Adult patients only
mimic_patients_admission_df = mimic_patients_admission_df[(mimic_patients_admission_df.AGES >= 18)]

# %% [markdown]
# ### ICD-9 Codes table

# %%
mimic_diagnoses_df = pd.read_csv(PATH + 'mimic-III/DIAGNOSES_ICD.csv')

# %%
mimic_patients_diagnoses_df = pd.merge(mimic_patients_admission_df, mimic_diagnoses_df, on = ['SUBJECT_ID', 'HADM_ID'], how = 'inner')

# %%
# Out:
#    ROW_ID_x  SUBJECT_ID  HADM_ID  ... ROW_ID SEQ_NUM ICD9_CODE
# 0        21          22   165315  ...    151     1.0      9678
# 1        21          22   165315  ...    152     2.0      9693
# 2        21          22   165315  ...    153     3.0     E9502
# 3        21          22   165315  ...    154     4.0     E9503
# 4        21          22   165315  ...    155     5.0      3488
#
# [5 rows x 30 columns]

# %% [markdown]
# ### ICD-9 Descriptions table

# %%
mimic_diagnoses_descriptions_df = pd.read_csv(PATH + 'mimic-III/D_ICD_DIAGNOSES.csv')

# %%
# new_df = mimic_patients_diagnoses_df.merge(mimic_diagnoses_descriptions_df, left_on='ICD9_CODE', right_on='ICD9_CODE')
# dead = new_df[new_df['LONG_TITLE'].str.lower().str.contains('transplant')][new_df['HOSPITAL_EXPIRE_FLAG'] == 1]

# %%
# dead.groupby('ETHNICITY').size()
# Out:
# ETHNICITY
# ASIAN                               3
# ASIAN - CAMBODIAN                   2
# ASIAN - CHINESE                     1
# ASIAN - OTHER                       1
# BLACK/AFRICAN AMERICAN             27
# BLACK/HAITIAN                       2
# HISPANIC OR LATINO                  9
# HISPANIC/LATINO - PUERTO RICAN      3
# OTHER                               7
# PATIENT DECLINED TO ANSWER          3
# PORTUGUESE                          2
# UNABLE TO OBTAIN                    6
# UNKNOWN/NOT SPECIFIED              14
# WHITE                             269
# WHITE - OTHER EUROPEAN              1
# WHITE - RUSSIAN                     1
# dtype: int64

# %% [markdown]
# ## Occurrence and Mortality

# %% [markdown]
# ### By ethnicity

# %% [markdown]
# #### Creating new table with regex

# %%
# mimic_eth_mortality_df = mimic_patients_diagnoses_df

# mimic_eth_mortality_df = mimic_eth_mortality_df.replace(to_replace='^BLACK.*', value='BLACK', regex=True)
# mimic_eth_mortality_df = mimic_eth_mortality_df.replace(to_replace='^WHITE.*', value='WHITE', regex=True)
# mimic_eth_mortality_df = mimic_eth_mortality_df.replace(to_replace='^ASIAN.*', value='ASIAN', regex=True)
# mimic_eth_mortality_df = mimic_eth_mortality_df.replace(to_replace='^LATINO.*', value='LATINO', regex=True)
# mimic_eth_mortality_df = mimic_eth_mortality_df.replace(to_replace='^HISPANIC.*', value='LATINO', regex=True)
# mimic_eth_mortality_df = mimic_eth_mortality_df.replace(to_replace='^SOUTH AMERICAN.*', value='LATINO', regex=True)

# mimic_eth_mortality_df = mimic_eth_mortality_df.replace(to_replace='^CARIBBEAN ISLAND.*', value='OTHER', regex=True)
# mimic_eth_mortality_df = mimic_eth_mortality_df.replace(to_replace='^AMERICAN INDIAN.*', value='OTHER', regex=True)
# mimic_eth_mortality_df = mimic_eth_mortality_df.replace(to_replace='^MIDDLE EASTERN.*', value='OTHER', regex=True)
# mimic_eth_mortality_df = mimic_eth_mortality_df.replace(to_replace='^MULTI RACE ETHNICITY.*', value='OTHER', regex=True)
# mimic_eth_mortality_df = mimic_eth_mortality_df.replace(to_replace='^NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER.*', value='OTHER', regex=True)
# mimic_eth_mortality_df = mimic_eth_mortality_df.replace(to_replace='^PORTUGUESE.*', value='OTHER', regex=True)

# mimic_eth_mortality_df = mimic_eth_mortality_df.replace(to_replace='^UNABLE TO OBTAIN.*', value='UNKNOWN', regex=True)
# mimic_eth_mortality_df = mimic_eth_mortality_df.replace(to_replace='^UNKNOWN.*', value='UNKNOWN', regex=True)
# mimic_eth_mortality_df = mimic_eth_mortality_df.replace(to_replace='^PATIENT DECLINED TO ANSWER.*', value='UNKNOWN', regex=True)

# mimic_eth_mortality_df.to_csv('ETHNICITY_MORTALITY.csv', index = None, header=True)
# !cp ETHNICITY_MORTALITY.csv '/content/drive/My Drive/Master/UFMG/Dissertation/Exploration/mimic-III/'

# %% [markdown]
# #### Read table

# %%
mimic_eth_mortality_df = pd.read_csv(PATH + 'mimic-III/ETHNICITY_MORTALITY.csv')

# %% [markdown]
# #### Unique patient with multiple rows with same ICD9

# %%
eth_mortality_df = mimic_eth_mortality_df.groupby(['ICD9_CODE', 'ETHNICITY', 'HOSPITAL_EXPIRE_FLAG']).size().unstack()
eth_mortality_df = eth_mortality_df.reset_index()
eth_mortality_df.columns.names = [None]
eth_mortality_df.columns = ['ICD9_CODE', 'ETHNICITY', 'ALIVE', 'DEAD']
eth_mortality_df.insert(4, 'TOTAL', 'NULL')
eth_mortality_df = eth_mortality_df.fillna(0)

# Compute alive, dead and total
for index, row in eth_mortality_df.iterrows():
  eth_mortality_df.at[index, 'TOTAL'] = row.ALIVE + row.DEAD

# %% [markdown]
# #### Data integrity

# %%
# missing codes
print(len(mimic_eth_mortality_df[mimic_eth_mortality_df['ICD9_CODE'].isnull()]))
# total patients from original table
print(len(mimic_patients_diagnoses_df))
# total patients from new table
print(eth_mortality_df["TOTAL"].sum())
# Out:
# 44
# 569130
# 569086.0

# %%
# All patients
eth_mortality_group = eth_mortality_df.groupby('ETHNICITY')['TOTAL'].sum()
print(eth_mortality_group.sum())
print(eth_mortality_group)
# Out:
# 569086.0
# ETHNICITY
# ASIAN       12700.0
# BLACK       59730.0
# LATINO      19930.0
# OTHER       16228.0
# UNKNOWN     50605.0
# WHITE      409893.0
# Name: TOTAL, dtype: float64

# %%
eth_mortality_df = eth_mortality_df[(eth_mortality_df.ETHNICITY != 'OTHER') & (eth_mortality_df.ETHNICITY != 'UNKNOWN')]

# %% [markdown]
# #### Mortality significance

# %%
# 1. Mortality significance: only +2 patients dead
eth_mortality_significance_df = eth_mortality_df.loc[eth_mortality_df.DEAD > 2].copy()

# 2. Remove ICD9 codes with only ONE ETHNICITY
for index, row in eth_mortality_significance_df.iterrows():
  rows = eth_mortality_significance_df.loc[eth_mortality_significance_df.ICD9_CODE == row.ICD9_CODE]
  if (len(rows) == 1):
    eth_mortality_significance_df.drop(rows.index, inplace=True)

# %% [markdown]
# #### Ethinicity

# %%
# TODO:
# - REFACTORING!!!!! 

# 3. Binomial test

icd9_code, ethnicity, p_value_occ, p_value_mort = ([] for i in range(4))
asian_t, black_t, latino_t, white_t = ([] for i in range(4))
asian_d, black_d, latino_d, white_d = ([] for i in range(4))
icd_pass = True
 
for index, row in eth_mortality_significance_df.iterrows():
  if row.ICD9_CODE not in icd9_code: # icd must be evaluate only once
    icd_pass = True

  if icd_pass:
    rows = eth_mortality_significance_df[eth_mortality_significance_df["ICD9_CODE"] == row.ICD9_CODE]
    icd_pass = False
    
    asian_total, black_total, latino_total, white_total = 0, 0, 0, 0
    asian_dead, black_dead, latino_dead, white_dead = 0, 0, 0, 0
    asian_percentage_dead, black_percentage_dead, latino_percentage_dead, white_percentage_dead = 0, 0, 0, 0
    
    if rows.loc[rows.ETHNICITY == "ASIAN"]["TOTAL"].any():
      asian_total = rows.loc[rows.ETHNICITY == "ASIAN"]["TOTAL"].item()
      asian_dead = rows.loc[rows.ETHNICITY == "ASIAN"]["DEAD"].item()
      asian_percentage_dead = asian_dead / asian_total
      
    if rows.loc[rows.ETHNICITY == "BLACK"]["TOTAL"].any():
      black_total = rows.loc[rows.ETHNICITY == "BLACK"]["TOTAL"].item()
      black_dead = rows.loc[rows.ETHNICITY == "BLACK"]["DEAD"].item()
      black_percentage_dead = black_dead / black_total
      
    if rows.loc[rows.ETHNICITY == "LATINO"]["TOTAL"].any():
      latino_total = rows.loc[rows.ETHNICITY == "LATINO"]["TOTAL"].item()
      latino_dead = rows.loc[rows.ETHNICITY == "LATINO"]["DEAD"].item()
      latino_percentage_dead = latino_dead / latino_total
      
    if rows.loc[rows.ETHNICITY == "WHITE"]["TOTAL"].any():
      white_total = rows.loc[rows.ETHNICITY == "WHITE"]["TOTAL"].item()
      white_dead = rows.loc[rows.ETHNICITY == "WHITE"]["DEAD"].item()
      white_percentage_dead = white_dead / white_total
      
    asian_percentage_pop = asian_total/eth_mortality_group.ASIAN
    black_percentage_pop = black_total/eth_mortality_group.BLACK
    latino_percentage_pop = latino_total/eth_mortality_group.LATINO
    white_percentage_pop = white_total/eth_mortality_group.WHITE
    
    # If less common in asian/black/latino/white (considering total population) but they die more
    if ((asian_total != 0 and asian_dead != 0 and (asian_percentage_pop < (black_percentage_pop + latino_percentage_pop + white_percentage_pop)) and (asian_percentage_dead > (black_percentage_dead + latino_percentage_dead + white_percentage_dead))) or 
        (black_total != 0 and black_dead != 0 and (black_percentage_pop < (asian_percentage_pop + latino_percentage_pop + white_percentage_pop)) and (black_percentage_dead > (asian_percentage_dead + latino_percentage_dead + white_percentage_dead))) or
        (latino_total != 0 and latino_dead != 0 and (latino_percentage_pop < (black_percentage_pop + asian_percentage_pop + white_percentage_pop)) and (latino_percentage_dead > (black_percentage_dead + asian_percentage_dead + white_percentage_dead))) or
        (white_total != 0 and white_dead != 0 and (white_percentage_pop < (black_percentage_pop + latino_percentage_pop + asian_percentage_pop)) and (white_percentage_dead > (black_percentage_dead + latino_percentage_dead + asian_percentage_dead)))):
      
      # Values by ethnicity (for comparison)
      asian_t.append(asian_total), black_t.append(black_total), latino_t.append(latino_total), white_t.append(white_total)
      asian_d.append(asian_dead), black_d.append(black_dead), latino_d.append(latino_dead), white_d.append(white_dead)

      # Occurrences
      n_occ = asian_total + black_total + latino_total + white_total
      
      if ((asian_percentage_pop < (black_percentage_pop + latino_percentage_pop + white_percentage_pop)) and 
          (asian_percentage_dead > (black_percentage_dead + latino_percentage_dead + white_percentage_dead))):
        # asian
        x_occ = asian_total
        x_mort = asian_dead
        prob_occ = (n_occ - asian_total)/n_occ
        prob_mort = (black_percentage_dead + latino_percentage_dead + white_percentage_dead)/(n_occ - asian_total)
        ethnicity.append("ASIAN")
        icd9_code.append(rows.iloc[0]['ICD9_CODE'])
      elif ((black_percentage_pop < (asian_percentage_pop + latino_percentage_pop + white_percentage_pop)) and 
            (black_percentage_dead > (asian_percentage_dead + latino_percentage_dead + white_percentage_dead))): 
        # black
        x_occ = black_total
        x_mort = black_dead
        prob_occ = (n_occ - black_total)/n_occ
        prob_mort = (asian_percentage_dead + latino_percentage_dead + white_percentage_dead)/(n_occ - black_total)
        ethnicity.append("BLACK")
        icd9_code.append(rows.iloc[0]['ICD9_CODE'])
      elif ((latino_percentage_pop < (black_percentage_pop + asian_percentage_pop + white_percentage_pop)) and
            (latino_percentage_dead > (black_percentage_dead + asian_percentage_dead + white_percentage_dead))):
        # latino
        x_occ = latino_total
        x_mort = latino_dead
        prob_occ = (n_occ - latino_total)/n_occ
        prob_mort = (asian_percentage_dead + black_percentage_dead + white_percentage_dead)/(n_occ - latino_total)
        ethnicity.append("LATINO")
        icd9_code.append(rows.iloc[0]['ICD9_CODE'])      
      else:
        # white
        x_occ = white_total
        x_mort = white_dead
        prob_occ = (n_occ - white_total)/n_occ
        prob_mort = (asian_percentage_dead + black_percentage_dead + latino_percentage_dead)/(n_occ - white_total)
        ethnicity.append("WHITE")
        icd9_code.append(rows.iloc[0]['ICD9_CODE'])
         
      # p-value: binom test
      p_value_occ.append(binom_test(x = x_occ, n = n_occ, p = prob_occ, alternative = 'two-sided'))
      p_value_mort.append(binom_test(x = x_mort, n = x_occ, p = prob_mort, alternative = 'two-sided'))

# %% [markdown]
# #### Binomial test

# %%
dict = {'Ethnicity': ethnicity, 'ICD9': icd9_code, 'Occ p-value': p_value_occ, 
        'Mort p-value': p_value_mort, 'Asian Total': asian_t, 'Asian Dead': asian_d, 
        'Black Total': black_t, 'Black Dead': black_d, 'Latino Total': latino_t,
        'Latino Dead': latino_d, 'White Total': white_t, 'White Dead': white_d}  
    
binom_test_df = pd.DataFrame(dict)
binom_test_df = binom_test_df.merge(mimic_diagnoses_descriptions_df, left_on='ICD9', right_on='ICD9_CODE')
binom_test_df = binom_test_df.drop(['ROW_ID', 'ICD9_CODE', 'SHORT_TITLE'], axis=1)

pd.set_option("display.max_colwidth", 100)

# null hypothesis rejected: p-value < 0.05
binom_test_df[(binom_test_df['Occ p-value'] < 0.05) & (binom_test_df['Mort p-value'] < 0.05)]
# Out:
#     Ethnicity  ...                                                                                           LONG_TITLE
# 0       WHITE  ...                                                                          Other specified septicemias
# 1       WHITE  ...  Methicillin susceptible Staphylococcus aureus in conditions classified elsewhere and of unspecif...
# 2       WHITE  ...  Staphylococcus infection in conditions classified elsewhere and of unspecified site, other staph...
# 3       ASIAN  ...                                                  Chronic hepatitis C without mention of hepatic coma
# 4       WHITE  ...                                                                Candidiasis of other urogenital sites
# 5       WHITE  ...                                                                             Disseminated candidiasis
# 6       WHITE  ...                                                                                        Aspergillosis
# 7       WHITE  ...                                                                                          Sarcoidosis
# 8       BLACK  ...                                                     Malignant neoplasm of pancreas, part unspecified
# 9       BLACK  ...                                                          Malignant neoplasm of kidney, except pelvis
# 10      BLACK  ...                            Secondary and unspecified malignant neoplasm of intrathoracic lymph nodes
# 11      BLACK  ...                                    Secondary malignant neoplasm of other digestive organs and spleen
# 12      ASIAN  ...                                                        Secondary malignant neoplasm of adrenal gland
# 13      WHITE  ...                                       Multiple myeloma, without mention of having achieved remission
# 14      BLACK  ...                                                                Myelodysplastic syndrome, unspecified
# 15      WHITE  ...         Diabetes mellitus without mention of complication, type II or unspecified type, uncontrolled
# 16      WHITE  ...     Diabetes with ophthalmic manifestations, type II or unspecified type, not stated as uncontrolled
# 17      WHITE  ...  Diabetes with other specified manifestations, type II or unspecified type, not stated as uncontr...
# 18      WHITE  ...                                                                            Hypoglycemia, unspecified
# 19      WHITE  ...                                                                            Glucocorticoid deficiency
# 20      BLACK  ...                                                                                 Nutritional marasmus
# 21      WHITE  ...                                                                   Disorders of phosphorus metabolism
# 22      WHITE  ...                                                                                         Hypocalcemia
# 23      BLACK  ...                                                                                 Other fluid overload
# 24     LATINO  ...                                                                                       Hypopotassemia
# 25      WHITE  ...                                                                                    Other amyloidosis
# 26      WHITE  ...                                                                                       Morbid obesity
# 27      WHITE  ...                                                                  Iron deficiency anemia, unspecified
# 28      WHITE  ...                                                                     Anemia in chronic kidney disease
# 29      BLACK  ...                                                                             Other diseases of spleen
# ..        ...  ...                                                                                                  ...
# 102    LATINO  ...                                                  Iatrogenic cerebrovascular infarction or hemorrhage
# 103     BLACK  ...                                                      Cardiac complications, not elsewhere classified
# 104     BLACK  ...                                          Peripheral vascular complications, not elsewhere classified
# 105     BLACK  ...                                                      Urinary complications, not elsewhere classified
# 106    LATINO  ...                                       Other and unspecified infection due to central venous catheter
# 107     BLACK  ...                                                                                       Home accidents
# 108     WHITE  ...                                                        Accidents occurring in other specified places
# 109    LATINO  ...  Surgical operation with anastomosis, bypass, or graft, with natural or artificial tissues used a...
# 110     BLACK  ...  Other specified surgical operations and procedures causing abnormal patient reaction, or later c...
# 112     WHITE  ...                                                                                 Unspecified accident
# 113     WHITE  ...                                 Adrenal cortical steroids causing adverse effects in therapeutic use
# 114     WHITE  ...                      Other drugs and medicinal substances causing adverse effects in therapeutic use
# 115     WHITE  ...                        Infection with microorganisms without mention of resistance to multiple drugs
# 116     BLACK  ...                                            Personal history of malignant neoplasm of large intestine
# 117     BLACK  ...                                          Personal history of malignant neoplasm of bronchus and lung
# 118     ASIAN  ...                                                     Personal history of malignant neoplasm of breast
# 119     BLACK  ...                                      Personal history of malignant neoplasm of other parts of uterus
# 120     ASIAN  ...                                                   Personal history of malignant neoplasm of prostate
# 121     BLACK  ...                                                    Personal history of malignant neoplasm of bladder
# 122     WHITE  ...               Personal history of noncompliance with medical treatment, presenting hazards to health
# 123     ASIAN  ...                                                                                      History of fall
# 124     BLACK  ...                                                                                Hip joint replacement
# 125     BLACK  ...                                                                               Knee joint replacement
# 126     WHITE  ...                                                                                  Tracheostomy status
# 127     WHITE  ...                                                                                   Gastrostomy status
# 128     BLACK  ...                                                                                     Colostomy status
# 129     BLACK  ...                                                  Automatic implantable cardiac defibrillator in situ
# 130    LATINO  ...                                                    Other dependence on machines, supplemental oxygen
# 131     WHITE  ...                                                                     Awaiting organ transplant status
# 132     BLACK  ...                                                         Examination of participant in clinical trial
#
# [129 rows x 13 columns]

# %%
print(len(binom_test_df[(binom_test_df['Occ p-value'] < 0.05) & (binom_test_df['Mort p-value'] < 0.05)]))
# Out:
# 129

# %%
# Only cases with transplanted organs
pd.set_option("display.max_colwidth", 500)
binom_test_df.loc[binom_test_df.iloc[:, -1].str.lower().str.contains(r'transplant')]
# Out:
#     Ethnicity   ICD9  ...  White Dead                            LONG_TITLE
# 100     WHITE  99681  ...        35.0  Complications of transplanted kidney
# 101     BLACK  99682  ...        21.0   Complications of transplanted liver
# 131     WHITE  V4983  ...        21.0      Awaiting organ transplant status
#
# [3 rows x 13 columns]

# %%
# Only cases with heart problems - CODE ?
binom_test_df.loc[binom_test_df.iloc[:, -1].str.lower().str.contains(r'atrial')]
# Out:
# Empty DataFrame
# Columns: [Ethnicity, ICD9, Occ p-value, Mort p-value, Asian Total, Asian Dead, Black Total, Black Dead, Latino Total, Latino Dead, White Total, White Dead, LONG_TITLE]
# Index: []

# %%
patients_transp_liver_df = mimic_eth_mortality_df.loc[(mimic_eth_mortality_df.ICD9_CODE == "99682") & (mimic_eth_mortality_df.ETHNICITY == "BLACK")]
print(len(patients_transp_liver_df))

# %%
# Patient with duplicated icd9
patients_transp_liver_df.loc[(patients_transp_liver_df["SUBJECT_ID"] == 5882) & (patients_transp_liver_df["ICD9_CODE"] == "99682")]

# %% [markdown]
# #### MORE ABOUT PATIENT 5882

# %%
mimic_admission_df.loc[(mimic_admission_df["SUBJECT_ID"] == 5882)]
# Out:
#       ROW_ID  SUBJECT_ID  ...  HOSPITAL_EXPIRE_FLAG HAS_CHARTEVENTS_DATA
# 7863    7194        5882  ...                     0                    1
# 8003    7195        5882  ...                     0                    1
# 8004    7196        5882  ...                     0                    1
# 8005    7197        5882  ...                     1                    1
#
# [4 rows x 19 columns]

# %% [markdown]
# * 4 admissions in aprox. 3 years
#
# * In first admission patient was declared **white** (!) with liver failure
#
# * HADM_ID **185301** and **181631** have ICD9: **99682** - COMPLICATION OF TRANSPLANTED LIVER
#
# * 185301 and 181631 are not sequential (?)

# %%
patient_5882_df = mimic_diagnoses_df.loc[(mimic_diagnoses_df["SUBJECT_ID"] == 5882)]  
patient_5882_df.merge(mimic_diagnoses_descriptions_df, left_on='ICD9_CODE', right_on='ICD9_CODE').sort_values(by="ROW_ID_x")
# Out:
#     ROW_ID_x  ...                                                                                                                                                        LONG_TITLE
# 0      66135  ...                                                                                                               Chronic hepatitis C without mention of hepatic coma
# 1      66136  ...                                                                                                                                      Alcoholic cirrhosis of liver
# 2      66137  ...                                                                                                                                                        Bacteremia
# 3      66138  ...                                                                                                                                 Spontaneous bacterial peritonitis
# 4      66140  ...                                                                                                                             Congestive heart failure, unspecified
# 5      66142  ...                                                                                                                     Cirrhosis of liver without mention of alcohol
# 7      66143  ...                                                                                                                               Chronic kidney disease, unspecified
# 8      66144  ...                                                                                                                                      Liver replaced by transplant
# 9      66145  ...                                                                                                                                  Awaiting organ transplant status
# 10     66146  ...                                         Streptococcus infection in conditions classified elsewhere and of unspecified site, streptococcus, group D [Enterococcus]
# 11     66147  ...                                                                                                                            Other chronic pulmonary heart diseases
# 12     66148  ...                                                                       Diabetes with renal manifestations, type II or unspecified type, not stated as uncontrolled
# 13     66149  ...                                            Hypertensive chronic kidney disease, unspecified, with chronic kidney disease stage I through stage IV, or unspecified
# 14     66150  ...                                                                                                                     Depressive disorder, not elsewhere classified
# 15     66151  ...                                                                                     Infection with microorganisms without mention of resistance to multiple drugs
# 16     66152  ...                                                                                                                   Other septicemia due to gram-negative organisms
# 17     66153  ...                                                                                                                                         Acute respiratory failure
# 18     66154  ...                                                                                              Other complications due to other vascular device, implant, and graft
# 19     66155  ...                                                                                                                               Complications of transplanted liver
# 21     66156  ...                                                                                                                                              Candidiasis of mouth
# 22     66157  ...                                                                                                                 Intestinal infection due to Clostridium difficile
# 24     66158  ...                                                                                                                              Acute and subacute necrosis of liver
# 25     66159  ...                                                                                                              Acute kidney failure with lesion of tubular necrosis
# 27     66160  ...                                                                                                                                                          Acidosis
# 29     66161  ...                                                                                                                                                     Severe sepsis
# 30     66162  ...                                                                                                                                               Atrial fibrillation
# 6      66163  ...                                                                                                                     Cirrhosis of liver without mention of alcohol
# 32     66164  ...                                                        Diabetes mellitus without mention of complication, type II or unspecified type, not stated as uncontrolled
# 33     66165  ...                                                                                                                                Unspecified essential hypertension
# 34     66166  ...  Surgical operation with transplant of whole organ causing abnormal patient reaction, or later complication, without mention of misadventure at time of operation
# 20     66167  ...                                                                                                                               Complications of transplanted liver
# 26     66168  ...                                                                                                              Acute kidney failure with lesion of tubular necrosis
# 36     66169  ...                                                  Hypertensive chronic kidney disease, unspecified, with chronic kidney disease stage V or end stage renal disease
# 37     66171  ...                                                                                                                                                   Hyperpotassemia
# 38     66172  ...                                                                  Diabetes with other specified manifestations, type I [juvenile type], not stated as uncontrolled
# 23     66173  ...                                                                                                                 Intestinal infection due to Clostridium difficile
# 28     66174  ...                                                                                                                                                          Acidosis
# 39     66175  ...                                                                                                                          Unspecified protein-calorie malnutrition
# 40     66176  ...                                                                                                                Unspecified viral hepatitis C without hepatic coma
# 41     66177  ...                                                                                                                                            Hepatic encephalopathy
# 31     66178  ...                                                                                                                                               Atrial fibrillation
# 42     66179  ...                                                                                                                                          Hypotension, unspecified
# 43     66180  ...                                                                                                                                               Delusional disorder
# 44     66181  ...                                                                                                           Nonspecific abnormal results of function study of liver
# 35     66182  ...  Surgical operation with transplant of whole organ causing abnormal patient reaction, or later complication, without mention of misadventure at time of operation
#
# [45 rows x 8 columns]

# %% [markdown]
# #### Note events form patient 5882

# %%
note_events_patient_5882_df = pd.read_csv(PATH + 'mimic-III/sample_NoteEvents_patient5882.csv')

# %%
note_events_patient_5882_df
# Out:
#       row_id  ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 text
# 0      15832  ...  Admission Date:  [**2144-7-16**]              Discharge Date:   [**2144-7-31**]\n\nDate of Birth:  [**2082-11-29**]             Sex:   M\n\nService: MEDICINE\n\nAllergies:\nPatient recorded as having No Known Allergies to Drugs\n\nAttending:[**First Name3 (LF) 943**]\nChief Complaint:\n# Fever\n# Bacteremia\n\nMajor Surgical or Invasive Procedure:\n# PICC placement at left upper extremity\n# Diagnositic paracentesis\n# Paracentesis (3 L)\n\nHistory of Present Illness:\n61M h/o HCV cirrhosis ...
# 1      15833  ...  Admission Date:  [**2144-9-22**]              Discharge Date:   [**2144-10-7**]\n\nDate of Birth:  [**2082-11-29**]             Sex:   M\n\nService: MEDICINE\n\nAllergies:\nPatient recorded as having No Known Allergies to Drugs\n\nAttending:[**First Name3 (LF) 1377**]\nChief Complaint:\nN/V/tachycardia\n\nMajor Surgical or Invasive Procedure:\nnone\n\nHistory of Present Illness:\n61M w/ HCV cirrhosis s/p xplant (since failed and now s/p TIPS\nx2), DMII, HTN, and recent bacteremia (still on h...
# 2      15798  ...  Admission Date:  [**2141-8-31**]              Discharge Date:   [**2141-9-11**]\n\nDate of Birth:  [**2082-11-29**]             Sex:   M\n\nService: [**Doctor First Name 147**]\n\nAllergies:\nPatient recorded as having No Known Allergies to Drugs\n\nAttending:[**First Name3 (LF) 695**]\nChief Complaint:\nHCV Cirrhosis\n\nMajor Surgical or Invasive Procedure:\nS/P Orthtopic Liver Transplant\n\n\nHistory of Present Illness:\n58 yo male with HCV admitted for OLT\n\nPast Medical History:\nHCV\nE...
# 3      15799  ...  Admission Date:  [**2142-2-8**]              Discharge Date:   [**2142-3-16**]\n\nDate of Birth:  [**2082-11-29**]             Sex:   M\n\nService: SURGERY\n\nAllergies:\nPatient recorded as having No Known Allergies to Drugs\n\nAttending:[**First Name3 (LF) 668**]\nChief Complaint:\nMr. [**Known lastname **] is a 59 y.o. man with a hx of End-stage liver disease\ndue to Hepatitis C. He is status post orthotopic liver\ntransplantation on [**2141-9-1**], which has been complicated by acute\nce...
# 4      74124  ...  PATIENT/TEST INFORMATION:\nIndication: Congestive heart failure. Left ventricular function.\nHeight: (in) 69\nWeight (lb): 160\nBSA (m2): 1.88 m2\nBP (mm Hg): 169/68\nHR (bpm): 83\nStatus: Inpatient\nDate/Time: [**2144-7-23**] at 13:06\nTest: Portable TTE (Complete)\nDoppler: Full Doppler and color Doppler\nContrast: None\nTechnical Quality: Adequate\n\n\nINTERPRETATION:\n\nFindings:\n\nThis study was compared to the prior study of [**2144-7-17**].\n\n\nLEFT ATRIUM: Moderate LA enlargement.\...
# 5      74125  ...  PATIENT/TEST INFORMATION:\nIndication: Endocarditis.\nHeight: (in) 69\nWeight (lb): 154\nBSA (m2): 1.85 m2\nBP (mm Hg): 156/79\nHR (bpm): 71\nStatus: Inpatient\nDate/Time: [**2144-7-17**] at 16:31\nTest: Portable TTE (Complete)\nDoppler: Full Doppler and color Doppler\nContrast: None\nTechnical Quality: Adequate\n\n\nINTERPRETATION:\n\nFindings:\n\nThis study was compared to the prior study of [**2144-6-11**].\n\n\nLEFT ATRIUM: Mild LA enlargement.\n\nRIGHT ATRIUM/INTERATRIAL SEPTUM: Mildly ...
# 6      74126  ...  PATIENT/TEST INFORMATION:\nIndication: fever , positive PICC ,  cx for staph epi\nHeight: (in) 69\nWeight (lb): 149\nBSA (m2): 1.82 m2\nHR (bpm): 62\nStatus: Inpatient\nDate/Time: [**2144-6-11**] at 16:27\nTest: TTE (Complete)\nDoppler: Full Doppler and color Doppler\nContrast: None\nTechnical Quality: Adequate\n\n\nINTERPRETATION:\n\nFindings:\n\nThis study was compared to the prior study of [**2144-1-13**].\n\n\nLEFT ATRIUM: Elongated LA.\n\nRIGHT ATRIUM/INTERATRIAL SEPTUM: Normal RA size....
# 7      74127  ...  PATIENT/TEST INFORMATION:\nIndication: Left ventricular function.\nHeight: (in) 69\nWeight (lb): 150\nBSA (m2): 1.83 m2\nBP (mm Hg): 140/80\nHR (bpm): 48\nStatus: Outpatient\nDate/Time: [**2144-1-13**] at 11:00\nTest: TTE (Complete)\nDoppler: Full Doppler and color Doppler\nContrast: None\nTechnical Quality: Adequate\n\n\nINTERPRETATION:\n\nFindings:\n\nThis study was compared to the report of the prior study (images not\navailable) of [**2141-3-21**].\n\n\nLEFT ATRIUM: Mild LA enlargement.\...
# 8     170295  ...                                                                                                                                                                                                                                                                                                                  Atrial fibrillation with rapid ventricular response\nLateral ST-T changes are nonspecific\nSince previous tracing of [**2144-8-15**], atrial fibrillation with rapid ventricular\nresponse  new\n\n
# 9     170296  ...                                                                                                                                                                                                              Sinus rhythm.  First degree A-V delay.  Consider left atrial abnormality.\nBorderline prolonged QTc interval is non-specific but clinical correlation is\nsuggested.  Since previous tracing of [**2144-8-13**] the P-R interval is slightly\nlonger but otherwise, probably no significant change.\n\n
# 10    170297  ...                                                                                                                                                                                                                                                                                                                                                        Sinus rhythm. Mild Q-T interval prolongation. Since the previous tracing\nof [**2144-7-28**] QRS voltage hs decreased and the Q-T interval has shortened.\n\n
# 11    170298  ...                                                                                                                                                                                                                                                                                                                                                        Sinus bradycardia.  Voltage criteria for left ventricular hypertrophy.\nCompared to tracing of [**2144-7-23**] there is no significant diagnostic change.\n\n
# 12    170299  ...                                                                                                                                                                                                     Sinus rhythm. Left ventricular hypertrophy. Compared to the previous tracing\nof [**2144-7-9**] the rate has increased. The T waves now have a terminal biphasic\nappearance. The rate has increased. The T wave changes suggest active anterior\nischemia. Followup and clinical correlation are suggested.\n\n
# 13    170300  ...                                                                                                                                                                                                                                                                                                                   Sinus bradycardia. First degree A-V block. Prolonged QTc interval. No\nsignificant change compared to the previous tracing of [**2144-7-2**] except that the\nQTc interval is somewhat longer.\n\n
# 14    170301  ...                                                                                                                                                                                                                                                                                    Sinus rhythm. Non-specific inferior and lateral ST-T wave changes. Compared to\nthe previous tracing of [**2144-6-21**] the rate has increased. The Q-T interval remains\nprolonged. Otherwise, no diagnostic interim change.\n\n
# 15    170302  ...                                                                                                                                                                                                                                                                                                                                                                        Sinus bradycardia.  Prolonged Q-T interval.  Prominent U waves.  Compared to\ntracing on [**2144-6-18**] the U waves are more pronounced.\n\n
# 16    170550  ...                                                                                                                                                                                                                                                                                                                                                                                              Sinus bradycardia.  First degree A-V block.  Compared to tracing of [**2144-6-6**]\nbradycardia is new.\nTRACING #1\n\n
# 17    170551  ...                                                                                                                                                                                                                                                                                                                            Sinus rhythm.  Borderline first degree A-V block.  Poor R wave progression is\nprobably a normal variant.  Compared to tracing of [**2144-6-6**] no significant\ndiagnostic change.\n\n\n
# 18    170552  ...                                                                                                                                                                                                                                                                                                                                                                     Sinus rhythm.  Compared to previous tracing of [**2144-5-13**] Q-T interval\nprolongation no longer manifest.  Otherwise, no major change.\n\n\n
# 19    170553  ...                                                                                                                                                                                                                                                                                                                         Sinus rhythm\nPremature ventricular contractions\nLong QTc interval\nPoor R wave progression - probable normal variant\nSince previous tracing of [**2144-5-12**], no significant change\n\n
# 20    170554  ...                                                                                                                                                                                                                                                                                                                                          Sinus rhythm\nPremature ventricular contractions\nAnterior T wave changes are nonspecific\nSince previous tracing of [**2142-4-3**], ventricular premature complex seen\n\n
# 21    170555  ...                                                                                                                                                                                                                                                                                                                                                                          Normal sinus rhythm. Non-diagnostic repolarization abnormalities. Compared to\nthe previous tracing of [**2142-3-14**] no major change.\n\n
# 22    170556  ...                                                                                                                                                                             Baseline artifact. Sinus rhythm with mild P-R interval prolongation. Possible\nleft atrial abnormality and left ventricular hypertrophy. Non-specific\nST-T wave changes. Compared to the previous tracing of [**2142-2-25**] the heart rate\nis slower with a longer P-R interval. Anterolateral T wave inversions are\nnormalized.\n\n
# 23    170548  ...                                                                                                                                                                                                                                                                                                                                                                   Sinus bradycardia.  First degree A-V block.  Long QTc interval.  Compared to\ntracing #2 on [**2144-6-17**] no significant change.\nTRACING #3\n\n
# 24    170549  ...                                                                                                                                                                                                                                                                                                                                                          Irregular sinus bradycardia.  First degree A-V block.  Long QTc interval.\nCompared to tracing #1 on [**2144-6-16**] no significant change.\nTRACING #2\n\n
# 25    170557  ...                                                                                                                                                                                                                                                                                                                                         Technically difficult study\nSinus rhythm\nDiffuse T wave changes are nonspecific\nSince previous tracing of [**2142-2-23**], sinus rhythm now present; QRS voltage less\n\n
# 26    170558  ...                                                                                                                                                                                                                                                                         Atrial fibrillation with a rapid ventricular response. Since the previous\ntracing of [**2142-2-21**] atrial fibrillation with a rapid ventricular response is new.\nFurther ST-T wave abnormalities. Clinical correlation is suggested.\n\n
# 27    170559  ...                                                                                                                                                                                                                                                                                                                       Technically difficult study\nSinus rhythm\nVoltage criteria for left ventricular hypertrophy\nST-T wave abnormalities\nSince previous tracing of [**2142-2-10**], sinus rhythm now present\n\n
# 28    170560  ...                                                                                                                                                                     Baseline artifact in lead V6\nAtrial fibrillation with rapid ventricular response\nModest nonspecific intraventricular conduction delay\nDiffuse nonspecific ST-T wave abnormalities\nClinical correlation is suggested\nSince previous tracing of [**2142-2-8**], sinus bradycardia absent and\nintraventricular conduction delay decreased\n\n
# 29    170561  ...                                                                                                                                                                                                                                                                     Sinus bradycardia. Left atrial abnormality. Intraventricular conduction delay.\nCompared to the previous tracing of [**2141-12-24**] the QRS interval has increased.\nThere is Q-T interval prolongation. Clinical correlation is suggested.\n\n
# ..       ...  ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 207  1339317  ...  Nursing Progress Note\nPlease See carvue for specifics:\nNeuro: Pt becoming increasingly confused over coarse of day.  Pt thrashing in bed.  unaware of surrounding.  + hallucinations at times. Ammonia level wnl (see carvue for specifics).  Pt given 2.5 haldol X12 with + effect.   LFT's remain on the  rise.\nCV:  HR and BP stable most of day w/ occ HTN with increased agitation.  Pt to IR for choliangio.  PT into rapid afib to 180's w/ increased BP to 170's.  Converted to sinus post 15mg IV lo...
# 208  1339293  ...                                                                                                                                                                                                                                                                                     Resp Care Note:\n\nPt cont intub with OETT and on mech vent as per Carevue. Lung sounds coarse rhonchi suct sm-mod th yellow sput. ABGs stable able to switch to PSV. Pt in NARD on present settings will wean PSV as [** **].\n
# 209  1339294  ...                                                                                                                                                                                                                                                                                                                                                                                                                                                          Update\nContinue to monitor for signs of organ rejection.\n
# 210  1339295  ...  Update\nO: Pt s/p cadaveric liver transplant [**9-1**].\nCv status: sr-> sb(subseq to lopressor 10 iv) no ectopics w systolic htn. Minimal stimulation elicit htnive episodes  w sbp->180-190's.. Medicated for pain w improved bp control. Co 6-9 liters w Svo2 70's to 80's. Distal pulses palp (dp's/pt's bilat). Extrems cool to touch.\n\nResp status: Abg adeq on cpap w ps 10 peep 5. Bbs coarse to clear, lavage and suctioned for thick yellow(icteric) sputum. Copious oral secretions suctioned q2h-q...
# 211  1339296  ...                                                                                                                                                                                                                                                                             Respiratory Care\nPt weaned to CPAP/PSV of [**4-19**], talerating the settings well. Slow to awaken, appropriate responses with head nodding when awake. Physcians opting to hold extubation until morning. Returned to 15/5 PSV/PEEP.\n
# 212  1339297  ...  CONDITION UPDATE\nVSS. HYPERTENSIVE THIS AM.  STARTED ON IV HYDRALAZINE - SBP CONTROLLED.  AFEBRILE.  MUCH MORE ALERT TODAY.  CONSISTENTLY FOLLOWING COMMANDS.  MOVING ALL EXTREMITIES.  NODDING HEAD APPROPRIATELY TO QUESTIONING.  NO VENT CHANGES THIS SHIFT.  SATS GOOD. ABG'S ACCEPTABLE. LUNGS CLEAR TO COARSE THROUGHOUT.  MIN SUCTIOINING FOR THICK, YELLOW SPUTUM.  NGT TO LWS, SM [** 1932**] OF BILIOUS DRAINAGE OUT.  CONT ON INSULIN DRIP.  SURGICL DRESSING TAKEN DOWN BY TXPLANT TEAM. SURGICAL I...
# 213  1339329  ...  NPN (1900-0700):\n\nEvents:\n- Pt c/o CP last eve [**5-24**] on [**Last Name (un) 1943**] pain scale. EKG done w/o changes. Dr. [**Last Name (STitle) 1944**] notified. Pt stated his pain occurs while coughing. He initially denied pain med as pain decreased to [**3-24**] w/o med, but w/in an hour pain inc back to [**5-24**]...given 0.5mg IV dilaudid w/ good effect.  Pain 0/10 w/in half hour. Stated " I feel really good".\n\n-Given 10mg IV lasix x 1 in attempt to reach negative fluid balance.\...
# 214  1339330  ...                                                                                                                                                                                                                                                                                                                                                                       Respiratory care:\nPatient received albuterol/atrovent nebulizer therapy, as noted in CareVue.  No significant changes after each treatment.\n
# 215  1339286  ...  Sicu Admit Note\nSee Flowsheet for Specifics:\nPt arrived from OR  with anesthesia S/P Cadaver liver Transplant.\nNeuro: Anesthesia not reversed.  PERRL.  No movement. Cough and gag present.\nCV: 2 500CC NS Bolus given for SBP<100 with transient effect.  2U PRBCs given for HCT of 24.  Neo started and titrated to maintain sbp>100.  PT in ST with no ectopy.  IVF @ 125.  CCO in place and calibrated. unable to wedge. MD [**Hospital1 125**] informed.  CO falling slightly with NEO gtt.\nResp:  Lun...
# 216  1339287  ...                                                                                                                                                                                                                                                                                                                                             Respiratory Care\nPt admitted to the unit secondary to liver transplant. Breath sounds equal. Good chest movement. Vent settings changed in accordance to ABG resluts.\n
# 217  1339310  ...  CONDITION UPDATE\nD: PT OPENS EYES SPONTANEOUSLY AND IS ABLE TO FOLLOW COMMANDS INCONSISTENTLY. HE MOVES ALL EXTREMITIES. 2MG OF MORPHINE FOR PAIN WITH GOOD RELIEF.\nCARDIAC: PT WITH EPISODE OF AFIB RATE OF 110-130. SBP 130/60.\nA: EKG DONE, LABS CHECKED. PT TREATED WITH LOPRESSOR 5MG IV X5 FOR TOTAL OF 25MG.\nR: PT CONVERTED TO NSR RATE OF 80. SBP UNCHANGED WITH LOPRESSOR. CK WITH ISOS AND TROPONIN TO BE SENT.\nRESP: BS ARE COARSE AND DIMINISHED IN THE BASES. PT SUCTIONED FOR THICK YELLOW S...
# 218  1339311  ...  CONDITION UPDATE\nD: PLEASE SEE CAREVUE FOR SPECFICS\nNEURO: AROUSABLE TO VOICE, FOLLOWS COMMANDS, ABLE TO LIFT ARMS OFF OF BED, MOVES LE ON BED, PURPOSEFUL MOVEMENT OF ARMS NOTED WHEN PT NOT RESTRAINED\nCV: PT PRESENTLY IN NSR WITH OCCASIONAL PAC AND RARE RUNS OF V TACH TODAY. BP STABLE. LOPRESSOR GIVEN AS ORDERED\nRESP: WEANED TO CPAP WITH 5 IPS, ABG GOOD, BS DIMINISHED IN RLL OTHERWISE COARSE BUT CLEARS WITH SUCTIONING. SX FOR MOD AMTS THICK WHITE SECRETONS\nGI: ABD SOFT, + BS, FIB CHANGE...
# 219  1339324  ...  PLEASE REFER TO CAREVUE FOR COMPLETE ASSESSMENT AND SPECIFICS.\n\nNEURO: PT [**Name (NI) 1938**] MORE [**Name (NI) 462**] THROUGHOUT DAY, INCONSISTENTLY FOLLOWS COMMANDS, MAE SPONT/[**Name (NI) 1939**], PT IS [**Name (NI) **] HALLUCINATING AND INAPPROPRIATE AT TIMES, REORIENTED AS NEEDED AND REASSURED.\n\nCV: HR 78-90, NSR W/ PVC'S, AT APPROXIMATELY 14:15, PT HR INC TO 120-140'S ST, RECEIVED LOPRESSOR 5MG X2 W/ GOOD RESULT HR DOWN. SBP 149-163.\n\nRESP: LUNG SOUNDS COARSE, RR 15-34, O2 SAT 9...
# 220  1339325  ...  neuro: Confused at times and angry. Asking to sign out of the hospital. Finnally fell asleep at 0430am.mso4 1 mg for agitation,\ncv/resp nsr/st. bp elevated. not responding well to meds. iv hydralazine given with good effect. resp stable. o2 100% on 2lnp. lungs coarse. refuses to allow RN to check his temp.\ngi/gu npo. mouth swabs prn. fib bag [** 657**] minimal stool out.\nfoley with icteric urine. good [** **].\nbile drains [** 657**] on RUQ. min drainage,\ncompression sleeves [** 657**]. ...
# 221  1339326  ...  PLEASE REFER TO CAREVUE FOR COMPLETE ASSESSMENT AND SPECIFICS.\n\nNEURO: PT A&O X1, MAE SPONT/[** 1939**], FOLLOWING COMMANDS INCONSISTENTLY, INAPPROPRIATE CONVERSATION, REORIENTED AS NEEDED.\n\nCV: HR 76-84, NSR W/ PVC'S, AT APPROXIMATELY 16:65, PT WENT INTO RAPID AFIB HR 130'S, MEDICATED W/ LOPRESOOR 5MG IVP X2, HR DOWN TO 90-100'S, REMAINS IN AFIB. DR. [**Last Name (STitle) **] AWARE.\n\nRESP: LUNG SOUNDS COARSE, O2 SAT 97-100% ON R/A, ENC TO C/DB. WEAK COUGH HOWEVER PT WAS ABLE TO EXPECT...
# 222  1339327  ...                                                                                                                                                                                                                    focus hemodynmic\ndata: confused to time and place. sitter at the bedside. stool bag replaced x4. lg [** **] of stool. u.o > 50cc/hr. tpn infusing. picc port clotted and 2nd port patent. k 3.6 and repleted with 20meq kcl iv over 2hrs. [** **] 25.0 ho notified.\nreponse: monitor closely.\n
# 223  1339328  ...  MICU NSG 7A-7PM\nPT IS A 61 YO MAN WITH LONG PMEDHX ADMITTED TO MICU 6 AFTER AN EPISODE OF RESP DISTRESS AND PULMONARY EDEMA DURING CT SCAN.\n\n--PMEDHX--LIVER FAILURE HEP C CIRRHOSIS, S/P TRANSPLANT [**2140**] WITH REJECTION, STAGE I VARICES, SBP, S/P TIPS FOR RECURRENT ASCITES, KLEBSIELLA PNEUMONIAE BACTERMIA SENSITIVE TO MEROPENEM AND RESISTANT TO ZOSYN, RENAL INSUFFICIENCY, DM WITH NEPHROPATHY, MULITPLE LUNG NODULES, C.DIFF, VRE, CHOLANGITIS, FTT, HTN, DVT RIGHT ARM.\n\n--ALLERGIES--NKA\...
# 224  1339337  ...  Nursing Progress Note 1900-0700\n*Full Code: ? discuss CMO w/ pt and wife today.  Pt stated to this nurse last night that he would not want to be intubated, no dialysis, but would want CPR if his heart went into a fatal rhythm.  MD updated and further discussions are planned for today.\n\n*Access:  RIJ TLC\n\n*NKDA\n\n** Please see admit note/FHP for admit info and hx.\n\nNeuro:  pt sleeping off and on, easily arousable though lethargic.  follows commands, able to make needs known (asking fo...
# 225  1339312  ...  Nursing Progress Note\nPlease see carvue for specifics:\nNeuro: Pt is [**Name (NI) **] noted improving MS [**First Name (Titles) **] [**Last Name (Titles) **].  Follows commands inconsistantly.  Able to make needs known via gesture and nodding.  Moving all extremities.  + Purposeful movements.\nCV:  No gtt's.  BP HTN at X's.  Lopressor Q6hrs as ordered.  HR SR no noted ectopy.  +PP +CSM.  Lasix gtt stopped pt making adequate urine.  CVP 4-6 over noc.\nResp:  Remains intubated on CPAP .35Fi02...
# 226  1339313  ...                                                                                                                                                                                                                                                                                                                                                                                pt remained on PSV throughout PM. pt's SpO2 dropped once and was improved without difficulty by ambo and sx. RSBI to be done in AM.\n
# 227  1339338  ...  MICU7 RN Note 0700-1900\n\nEvents:  paracentesis tap @ bedside, recieved Albumin, ^ Renal function oliguric, renal team following. called out to [**Hospital Ward Name 3**] 10 refer to Transfer note.\n\nNeuro/Pain: Awake [**Hospital Ward Name **] oriented x3 slow to respond drifts off to sleep. MAE random and to command very weak has difficulty lifting extremities. Pain management: denied\s pain @ rest c/o abd discomfort w/palpation.\n\nCV:  HR 60-70 NSR freq PAC rare PVC, NBP 100-127/55-65 M...
# 228  1339339  ...  Nursing Progress Note 1900-0700\n*DNR/DNI (Corroborated w/ Dr. [**First Name4 (NamePattern1) 978**] [**Last Name (NamePattern1) **]), to be discussed further w/ wife and [**Name2 (NI) **] today.\n\n*Access:  RIJ TLC\n\n*NKDA\n\n** Please see admit note/FHP for admit info and hx.\n\nNeuro:  pt Lethargic but A&Ox3, follows commands, was able to take phone calls from [**Name2 (NI) **] and have discussions, albe to feed self, helps w/ turns and turns by self @ times.  No c/o pain.\n\nCardiac:  N...
# 229  1339322  ...  NPN  0700-1900;\n\nO: WHAT THE. CHAIR?, WHAT STATE AM I IN ? WHY DO HAVE THIS LIE DETECTOR ON ME? YOU CANT ELECTROCUTE ME.\nS; VERY SOMULENT THIS MORNIING AND DIFFICULT TO ROUSE AT TIMES ? DUE TO HALDOL .CONFUSED AND DISORIENTATED AT TIMES. AT TIMES WILL STATE NAME AND HOSPITAL . HOSPITAL IN [**Location (un) **] DOES NOT KNOW DATE TIME YEAR.\nUNABLE TO FOCUS OR FOLLOW SIMPLE COMMANDS CONSISTENTLY. OOB TO CHAIR WEIGHT BEARING AND TAKING A COUPLE OF STEPS  WITH PT  AND SECOND ASSIST PLAN TO [*...
# 230  1339323  ...  NPN (NOC):\n\nCARDIAC:  REMAINS IN NSR ON LOPRESSOR 75 MG PO TID.  SBP'S RANGE FROM 140-170.\n\nRESP:  RR TEENS TO 20'S, REG, UNLABORED.  + PROD COUGH, NEEDED NTS X 1 OVERNOC.  SATS HIGH 90'S ON 4 LITERS NC.\n\nNUERO:  REMAINS LATHARGIC BUT EASY TO AROUSE.  IS CONFUSED AND DISORIENTED.  APPEARS TO BE IN PAIN W/ ANY MOVEMENT.  IVMS 1 MG IV GIVEN W/ SOME EFFECT SO WE COULD GET HIM WASHED UP.\n\nENDO:  SSI X 2 OVERNOC.\n\nRENAL:  UO MORE THAN ADEQUATE.  NO 'LYTE REPLACMENT NEEDED.\n\nGI:  [** 1...
# 231  1339335  ...  MICU 7 NPN:\n61 y/o male with pmhx: HCV cirrhosis s/p failed transplant and TIPS procedures x2, DM type 2, HTN, and recent klebsiella bacteremia and DVT.  Was at home receiving IV abx via PICC and developed low grade fevers, N/V, tachcardia and found hypotensive by VNA. Pt. also stating he had not voided in 24hrs. Admitted to [**Hospital1 41**] for w/u. Was on [**Hospital Ward Name 3**] 10 and became tachycardic with HR up to 150s and lactate found to be 5.4. Transferred to MICU for closer m...
# 232  1339336  ...  MICU 7: RN Note 0700-1900\n\nEvents:  Family meeting; Full Code; Pt does not want dialysis; Agreed to Central Line Placement, Blood products, Diagnostic paracentesis; Bladder pressure;  FFP x2; Bicarb; Stool culture; Blood culture; IVFB;\n\nNeuro:  AAO; Weak; Reports burning sensation upper abdomen. MAE.  Pt requested to use commode but not OOB all day.  Pt agreed to bedpan.\n\nCV:  SR 70s.  BP 98-124/60-70.  IVF bolus x1L (anuric/sepsis) and 3 amps of bicarb x 1 Liter for bicarb 15. PICC Ri...
# 233  1339298  ...  Update\nO: S/P Cadaveric liver transplant [**9-1**]\n\nCv status: sr no ectopics w episodes htn w  minimal pt. activity &/or stimulation-> responsive to hydralazine as ordered q6h.Bilat dp/pt's palp, extrems cool to touch.Co/Ci hyperdynamic Svo2 70's to 80's CCO recalibrated\n\nResp status: Resting comfortably overnight on cpap peep5 & ps10. Bbs equal and coarse throughout-> clears w freq lavage suct.for lg amts thick clear secretions. Abg adeq on above settings, plan wean to extub today if ...
# 234  1339299  ...                                                                                                                                                                                                                                                                           Respiratory Care\nPt remain intubated and on vent support, PS weaned to 5 Good Am RSBI(41) SX [**Last Name (un) 473**] thick yellow secretion, BS coares, Good cough [**Last Name (un) 1933**], SBT started at 5:15 posible extub today.\n
# 235  1339300  ...  Nursing Progress Note:\nPlease refer to CareVue and remarks for details.\n     Pt is A&Ox2 (self and month/year; pt thought that he was at [**Hospital6 1934**]).  Follows commands, moves all extremities.  Pt able to make needs known; requesting for pain med approp.  Pt compliant with care.  Pt complaining of incisional and RUQ abdominal pain this AM after strong coughs.  Morphine 2mg IVP given x 2 with positive effect. Pt able to sleep after pain med given.\n     Afebrile, hr 70-90s (NSR), b...
# 236  1339301  ...  Update\nO: S/P cadaveric liver transplant [**9-1**]\nCv status: sr no ectopics. htn much better controlled w hydralzine/^ lopressor dosing. Transient episodes sbp > 160 r/t incisional pain, resolved w mso4 (med x 3 for pain w 2-4mg mso4 iv). Pa line dc'd yest.Tlc in place cvp 1-5 range, wt ^ slghtly.\n\nResp status: Open face mask 50% w adeq sats and abgs. Bbs coarse to clear (diminsh lt base)w dbc & raising mod thick clear secretions.Alb mdi's q4h as ordered. Inc Spirometry moving [**Teleph...
#
# [237 rows x 11 columns]

# %%
print(note_events_patient_5882_df["text"].iloc[1])

# %% [markdown]
#  ### Patient awaiting for transplant

# %%
# Ethnicity: white
# patients_awaiting_transp_group1_dead_df = mimic_eth_mortality_df.loc[(mimic_eth_mortality_df.ICD9_CODE == "V4983") & (mimic_eth_mortality_df.ETHNICITY == "WHITE") & (mimic_eth_mortality_df.HOSPITAL_EXPIRE_FLAG == 1)]
patients_awaiting_transp_group1_df = mimic_eth_mortality_df.loc[(mimic_eth_mortality_df.ICD9_CODE == "V4983") & (mimic_eth_mortality_df.ETHNICITY == "WHITE")]

# %%
patients_awaiting_transp_group1_df.groupby(['INSURANCE', 'HOSPITAL_EXPIRE_FLAG'])['SUBJECT_ID'].count()
# Out:
# INSURANCE   HOSPITAL_EXPIRE_FLAG
# Government  0                        2
#             1                        1
# Medicaid    0                       12
#             1                        4
# Medicare    0                       26
#             1                        6
# Private     0                       48
#             1                       10
# Name: SUBJECT_ID, dtype: int64

# %%
# Ethnicity: black
patients_awaiting_transp_group2_df = mimic_eth_mortality_df.loc[(mimic_eth_mortality_df.ICD9_CODE == "V4983") & (mimic_eth_mortality_df.ETHNICITY == "BLACK")]

# %%
patients_awaiting_transp_group2_df.groupby(['INSURANCE', 'HOSPITAL_EXPIRE_FLAG'])['SUBJECT_ID'].count()
# Out:
# INSURANCE  HOSPITAL_EXPIRE_FLAG
# Medicaid   0                        2
# Medicare   0                       13
# Private    0                        8
#            1                        3
# Name: SUBJECT_ID, dtype: int64
